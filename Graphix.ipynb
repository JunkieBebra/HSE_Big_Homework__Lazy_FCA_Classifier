# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Employee.csv')

# %%
cnt = 1
plt.figure(figsize=(12, 10))

for c in data.columns:
    vc = data[c].value_counts()
    plt.subplot(3, 3, cnt)
    plt.bar(np.sort(vc.index.astype(str)), vc.values, alpha=0.8)
    plt.grid(alpha=0.4)
    plt.title(c)
    if c == 'Age':
        plt.xticks(rotation=90)
    else:
        plt.xticks(rotation=0)
    cnt += 1

plt.tight_layout()
plt.show()

# %%
plt.cla()
vc = data['LeaveOrNot'].value_counts()
plt.bar(np.sort(vc.index.astype(str)), vc.values, alpha=0.8)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# > Output all such data which are duplicates but have different "LeaveOrNot"

# %%
# Identifying duplicate rows with different 'LeaveOrNot' values
duplicates_with_diff_leave = data[data.duplicated(subset=data.columns.difference(['LeaveOrNot']), keep=False)]
result = duplicates_with_diff_leave.groupby(list(data.columns.difference(['LeaveOrNot']))).filter(lambda x: x['LeaveOrNot'].nunique() > 1)
result
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 14    Bachelors         2012  Bangalore            3   37    Male          No
# 29      Masters         2017  New Delhi            2   30  Female          No
# 41      Masters         2017  New Delhi            2   23    Male          No
# 49    Bachelors         2013  Bangalore            3   30  Female          No
# 56    Bachelors         2016  Bangalore            3   38    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4611    Masters         2014  New Delhi            3   24    Male          No
# 4618    Masters         2017  New Delhi            3   38  Female          No
# 4635  Bachelors         2014  Bangalore            3   22  Female          No
# 4639  Bachelors         2017  Bangalore            3   28    Male          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
#
# ...

# %% [markdown]
# The data containing duplicates with differing "LeaveOrNot" values has been identified. Let me know if you need further analysis or specific actions on this result.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=729b1cc4-35f2-4c75-899d-e722545e10c4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
